# %%
import matplotlib.pyplot as plt
  
# create data
line1x = [184.21,171.71]
line1y = [874.90,762.84]

line2x = [171.71,206.32]
line2y = [762.84,648.60]

line3x = [206.32,246.52]
line3y = [648.60,565.69]

line4x = [246.52,248.98]
line4y = [565.69,493.15]

line5x = [184.21,300.82]
line5y = [874.90,644.64]

line6x = [300.82,368.49]
line6y = [644.64,592.07]

line7x = [368.49,418.42]
line7y = [592.07,585.52]

line8x = [418.42,463.30]
line8y = [585.52,580.94]

line9x = [300.82,335.37]
line9y = [644.64,700.68]

line10x = [335.37,406.09]
line10y = [700.68,651.82]

line11x = [406.09,461.72]
line11y = [651.82,635.03]

line12x = [461.72,511.29]
line12y = [635.03,629.62]

line13x = [335.37,347.63]
line13y = [700.68,760.34]

line14x = [347.63,415.74]
line14y = [760.34,727.84]

line15x = [415.74,462.91]
line15y = [727.84,718.36]

line16x = [462.91,503.70]
line16y = [718.36,719.13]

line17x = [347.63,353.91]
line17y = [760.34,830.19]

line18x = [184.21,353.91]
line18y = [874.90,830.19]

line19x = [353.91,415.36]
line19y = [830.19,817.16]

line20x = [415.36,449.78]
line20y = [817.16,803.13]

line21x = [449.78,483.21]
line21y = [803.13,792.39]

# plot lines
plt.plot(line1x, line1y, label = "line 1")
plt.plot(line2x, line2y, label = "line 2")
plt.plot(line3x, line3y, label = "line 3")
plt.plot(line4x, line4y, label = "line 4")
plt.plot(line5x, line5y, label = "line 5")
plt.plot(line6x, line6y, label = "line 6")
plt.plot(line7x, line7y, label = "line 7")
plt.plot(line8x, line8y, label = "line 8")
plt.plot(line9x, line9y, label = "line 9")
plt.plot(line10x, line10y, label = "line 10")
plt.plot(line11x, line11y, label = "line 11")
plt.plot(line12x, line12y, label = "line 12")
plt.plot(line13x, line13y, label = "line 13")
plt.plot(line14x, line14y, label = "line 14")
plt.plot(line15x, line15y, label = "line 15")
plt.plot(line16x, line16y, label = "line 16")
plt.plot(line17x, line17y, label = "line 17")
plt.plot(line18x, line18y, label = "line 18")
plt.plot(line19x, line19y, label = "line 19")
plt.plot(line20x, line20y, label = "line 20")
plt.plot(line21x, line21y, label = "line 21")
plt.legend()
plt.show()
